# %%
import numpy as np
import sklearn
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import imageio.v3 as iio
import os
from PIL import Image
import imagehash

# %% [markdown]
# # Data loading and Processing

# %%
Image_size = 96
Batch = 32
Random_seed = 42

train_Bi_raw = tf.keras.utils.image_dataset_from_directory(
    "Training_Bi/",
    validation_split=0.15,
    subset="training",
    seed=Random_seed,
    image_size=(Image_size, Image_size),
    batch_size=None
)

val_Bi_raw = tf.keras.utils.image_dataset_from_directory(
    "Training_Bi/",
    validation_split=0.15,
    subset="validation",
        seed=Random_seed,
        image_size=(Image_size, Image_size),
        batch_size=None
)

test_Bi_raw = tf.keras.utils.image_dataset_from_directory(
    "Test/",
    image_size=(Image_size, Image_size),
    batch_size=None,
    shuffle=False
)
# Out:
# Found 39375 files belonging to 2 classes.
# Using 33469 files for training.
# Found 39375 files belonging to 2 classes.
# Using 5906 files for validation.
# Found 8617 files belonging to 2 classes.

# %%
def focal_loss(gamma, alpha):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        bce = -y_true * tf.math.log(y_pred) - (1 - y_true) * tf.math.log(1 - y_pred)
        p_t = y_true * y_pred + (1 - y_true) * (1 - y_pred)
        focal_weight = alpha * tf.pow(1 - p_t, gamma)
        return tf.reduce_mean(focal_weight * bce)
    return loss


def augment(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.rot90(image, k=tf.random.uniform((), 0, 4, dtype=tf.int32))
    image = tf.image.random_brightness(image, max_delta=0.3)
    image = tf.image.random_contrast(image, lower=0.7, upper=1.4)
    image = tf.image.random_saturation(image, lower=0.6, upper=1.6)
    image = tf.image.random_hue(image, max_delta=0.05)
    
    # Haze - fixed with tf.cond
    haze_intensity = tf.random.uniform((), 0.05, 0.25)
    haze = tf.ones_like(image) * 0.7
    image = tf.cond(
        tf.random.uniform(()) > 0.5,
        lambda: image * (1 - haze_intensity) + haze * haze_intensity,
        lambda: image
    )

    # Blur - fixed with tf.cond
    def apply_blur(img):
        img = tf.expand_dims(img, 0)
        img = tf.nn.avg_pool2d(img, ksize=3, strides=1, padding='SAME')
        return tf.squeeze(img, 0)

    image = tf.cond(
        tf.random.uniform(()) > 0.6,
        lambda: apply_blur(image),
        lambda: image
    )

    image = tf.clip_by_value(image, 0.0, 1.0)
    return image, label

def normalize(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

def compute_class_weights(ds):
    labels = np.array([y.numpy() for _, y in ds])
    counts = np.bincount(labels)
    total = len(labels)
    weights = {i: total / (len(counts) * c) for i, c in enumerate(counts)}
    print(f"Class weights: {weights}")
    return weights

# %%
class_weights = compute_class_weights(train_Bi_raw)

train_ds = (
    train_Bi_raw
    .map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(Batch)
    .prefetch(tf.data.AUTOTUNE)
)
val_ds = (
    val_Bi_raw
    .map(normalize, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(Batch)
    .prefetch(tf.data.AUTOTUNE)
)
test_ds = (
    test_Bi_raw
    .map(normalize, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(Batch)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# Class weights: {0: 0.787542943197327, 1: 1.3694353518821605}

# %%
model = keras.models.Sequential([
    
    keras.layers.Conv2D(8, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(8, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),
   
    keras.layers.Conv2D(32, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(32, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.3),
   
    keras.layers.Conv2D(64, 3, activation='relu', padding='same'),
    keras.layers.GlobalAveragePooling2D(),

    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss=focal_loss(gamma=2.0, alpha=0.65),
    metrics=[
        'accuracy',
        keras.metrics.Recall(name='recall'),
        keras.metrics.Precision(name='precision'),
    ]
)

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=2,
        min_lr=1e-7
    ),
    keras.callbacks.ModelCheckpoint(
        'best_fire_model.keras',
        monitor='val_recall',
        save_best_only=True,
    )
]

history = model.fit(
    train_ds,
    epochs=30,
    validation_data=val_ds,
    class_weight=None,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.8338 - loss: 0.0674 - precision: 0.9073 - recall: 0.6069 - val_accuracy: 0.9065 - val_loss: 0.0397 - val_precision: 0.8484 - val_recall: 0.9031 - learning_rate: 1.0000e-04
# Epoch 2/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9285 - loss: 0.0377 - precision: 0.9342 - recall: 0.8650 - val_accuracy: 0.8927 - val_loss: 0.0590 - val_precision: 0.7867 - val_recall: 0.9649 - learning_rate: 1.0000e-04
# Epoch 3/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9394 - loss: 0.0323 - precision: 0.9532 - recall: 0.8770 - val_accuracy: 0.9367 - val_loss: 0.0310 - val_precision: 0.8927 - val_recall: 0.9378 - learning_rate: 1.0000e-04
# Epoch 4/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9416 - loss: 0.0310 - precision: 0.9567 - recall: 0.8800 - val_accuracy: 0.9526 - val_loss: 0.0282 - val_precision: 0.9428 - val_recall: 0.9251 - learning_rate: 1.0000e-04
# Epoch 5/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9447 - loss: 0.0298 - precision: 0.9619 - recall: 0.8834 - val_accuracy: 0.9502 - val_loss: 0.0286 - val_precision: 0.9361 - val_recall: 0.9256 - learning_rate: 1.0000e-04
# Epoch 6/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9450 - loss: 0.0292 - precision: 0.9617 - recall: 0.8845 - val_accuracy: 0.9523 - val_loss: 0.0264 - val_precision: 0.9440 - val_recall: 0.9228 - learning_rate: 1.0000e-04
# Epoch 7/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9466 - loss: 0.0284 - precision: 0.9622 - recall: 0.8888 - val_accuracy: 0.9482 - val_loss: 0.0291 - val_precision: 0.9225 - val_recall: 0.9354 - learning_rate: 1.0000e-04
# Epoch 8/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9480 - loss: 0.0277 - precision: 0.9648 - recall: 0.8900 - val_accuracy: 0.9414 - val_loss: 0.0290 - val_precision: 0.9036 - val_recall: 0.9382 - learning_rate: 1.0000e-04
# Epoch 9/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - accuracy: 0.9505 - loss: 0.0263 - precision: 0.9659 - recall: 0.8961 - val_accuracy: 0.9585 - val_loss: 0.0235 - val_precision: 0.9735 - val_recall: 0.9102 - learning_rate: 5.0000e-05
# Epoch 10/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9508 - loss: 0.0262 - precision: 0.9654 - recall: 0.8973 - val_accuracy: 0.9587 - val_loss: 0.0234 - val_precision: 0.9754 - val_recall: 0.9088 - learning_rate: 5.0000e-05
# Epoch 11/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9509 - loss: 0.0256 - precision: 0.9638 - recall: 0.8994 - val_accuracy: 0.9485 - val_loss: 0.0254 - val_precision: 0.9225 - val_recall: 0.9364 - learning_rate: 5.0000e-05
# Epoch 12/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9516 - loss: 0.0257 - precision: 0.9671 - recall: 0.8980 - val_accuracy: 0.9594 - val_loss: 0.0232 - val_precision: 0.9629 - val_recall: 0.9233 - learning_rate: 5.0000e-05
# Epoch 13/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - accuracy: 0.9522 - loss: 0.0250 - precision: 0.9635 - recall: 0.9034 - val_accuracy: 0.9580 - val_loss: 0.0234 - val_precision: 0.9896 - val_recall: 0.8933 - learning_rate: 5.0000e-05
# Epoch 14/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 32s 30ms/step - accuracy: 0.9532 - loss: 0.0247 - precision: 0.9650 - recall: 0.9046 - val_accuracy: 0.9616 - val_loss: 0.0223 - val_precision: 0.9681 - val_recall: 0.9242 - learning_rate: 5.0000e-05
# Epoch 15/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9531 - loss: 0.0246 - precision: 0.9661 - recall: 0.9032 - val_accuracy: 0.9641 - val_loss: 0.0219 - val_precision: 0.9720 - val_recall: 0.9275 - learning_rate: 5.0000e-05
# Epoch 16/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 33s 31ms/step - accuracy: 0.9550 - loss: 0.0238 - precision: 0.9668 - recall: 0.9080 - val_accuracy: 0.9650 - val_loss: 0.0216 - val_precision: 0.9825 - val_recall: 0.9195 - learning_rate: 5.0000e-05
# Epoch 17/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 32s 31ms/step - accuracy: 0.9555 - loss: 0.0234 - precision: 0.9664 - recall: 0.9097 - val_accuracy: 0.9634 - val_loss: 0.0212 - val_precision: 0.9607 - val_recall: 0.9373 - learning_rate: 5.0000e-05
# Epoch 18/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 33s 31ms/step - accuracy: 0.9558 - loss: 0.0232 - precision: 0.9658 - recall: 0.9111 - val_accuracy: 0.9656 - val_loss: 0.0205 - val_precision: 0.9731 - val_recall: 0.9307 - learning_rate: 5.0000e-05
# Epoch 19/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 33s 31ms/step - accuracy: 0.9567 - loss: 0.0230 - precision: 0.9672 - recall: 0.9123 - val_accuracy: 0.9650 - val_loss: 0.0210 - val_precision: 0.9969 - val_recall: 0.9059 - learning_rate: 5.0000e-05
# Epoch 20/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 34s 32ms/step - accuracy: 0.9571 - loss: 0.0228 - precision: 0.9672 - recall: 0.9135 - val_accuracy: 0.9665 - val_loss: 0.0205 - val_precision: 0.9969 - val_recall: 0.9102 - learning_rate: 5.0000e-05
# Epoch 21/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 25s 24ms/step - accuracy: 0.9587 - loss: 0.0216 - precision: 0.9679 - recall: 0.9173 - val_accuracy: 0.9675 - val_loss: 0.0197 - val_precision: 0.9850 - val_recall: 0.9242 - learning_rate: 2.5000e-05
# Epoch 22/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 32s 30ms/step - accuracy: 0.9612 - loss: 0.0215 - precision: 0.9714 - recall: 0.9209 - val_accuracy: 0.9683 - val_loss: 0.0196 - val_precision: 0.9875 - val_recall: 0.9242 - learning_rate: 2.5000e-05
# Epoch 23/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 32s 30ms/step - accuracy: 0.9604 - loss: 0.0215 - precision: 0.9692 - recall: 0.9208 - val_accuracy: 0.9695 - val_loss: 0.0199 - val_precision: 0.9954 - val_recall: 0.9200 - learning_rate: 2.5000e-05
# Epoch 24/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 32s 30ms/step - accuracy: 0.9616 - loss: 0.0211 - precision: 0.9712 - recall: 0.9223 - val_accuracy: 0.9641 - val_loss: 0.0211 - val_precision: 0.9969 - val_recall: 0.9036 - learning_rate: 1.2500e-05
# Epoch 25/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 23s 22ms/step - accuracy: 0.9621 - loss: 0.0209 - precision: 0.9695 - recall: 0.9252 - val_accuracy: 0.9660 - val_loss: 0.0202 - val_precision: 0.9969 - val_recall: 0.9088 - learning_rate: 1.2500e-05
# Epoch 26/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 32s 31ms/step - accuracy: 0.9612 - loss: 0.0209 - precision: 0.9698 - recall: 0.9224 - val_accuracy: 0.9682 - val_loss: 0.0194 - val_precision: 0.9929 - val_recall: 0.9186 - learning_rate: 6.2500e-06
# Epoch 27/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 40s 30ms/step - accuracy: 0.9623 - loss: 0.0205 - precision: 0.9693 - recall: 0.9261 - val_accuracy: 0.9709 - val_loss: 0.0192 - val_precision: 0.9950 - val_recall: 0.9242 - learning_rate: 6.2500e-06
# Epoch 28/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 31s 29ms/step - accuracy: 0.9627 - loss: 0.0205 - precision: 0.9716 - recall: 0.9250 - val_accuracy: 0.9668 - val_loss: 0.0199 - val_precision: 0.9964 - val_recall: 0.9116 - learning_rate: 6.2500e-06
# Epoch 29/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 32s 30ms/step - accuracy: 0.9625 - loss: 0.0207 - precision: 0.9698 - recall: 0.9260 - val_accuracy: 0.9680 - val_loss: 0.0194 - val_precision: 0.9964 - val_recall: 0.9148 - learning_rate: 6.2500e-06
# Epoch 30/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - accuracy: 0.9632 - loss: 0.0204 - precision: 0.9710 - recall: 0.9270 - val_accuracy: 0.9700 - val_loss: 0.0191 - val_precision: 0.9949 - val_recall: 0.9219 - learning_rate: 3.1250e-06

# %%
loss, acc, recall, precision = model.evaluate(test_ds)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {acc:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test Precision: {precision:.4f}")

# Get probabilities
y_pred_prob = model.predict(test_ds)

# 2. Confusion matrix
true_labels = np.concatenate([y.numpy() for _, y in test_ds])

pred_classes = (y_pred_prob > 0.35).astype(int).flatten()
cm = confusion_matrix(true_labels, pred_classes)
print("Confusion Matrix:")
print(cm)

print("\nClassification Report:")
print(classification_report(true_labels, pred_classes, target_names=['No_Fire', 'Fire']))
# Out:
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6642 - loss: 0.1991 - precision: 0.7282 - recall: 0.2687
# Test Loss: 0.1991
# Test Accuracy: 0.6642
# Test Recall: 0.2687
# Test Precision: 0.7282
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# Confusion Matrix:
# [[4676  461]
#  [1845 1635]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      No_Fire       0.72      0.91      0.80      5137
#         Fire       0.78      0.47      0.59      3480
#
#     accuracy                           0.73      8617
#    macro avg       0.75      0.69      0.69      8617
# weighted avg       0.74      0.73      0.72      8617

# %%
for t in np.arange(0.25, 0.70, 0.05):
    pred_classes = (y_pred_prob > t).astype(int).flatten()
    print(f"Threshold {t:.2f}:", classification_report(true_labels, pred_classes, target_names=['No_Fire', 'Fire'], output_dict=True)['macro avg']['f1-score'])
# Out:
# Threshold 0.25: 0.6785790826433239
# Threshold 0.30: 0.7141939095166046
# Threshold 0.35: 0.6943189053987964
# Threshold 0.40: 0.6625715157210927
# Threshold 0.45: 0.6196854218772301
# Threshold 0.50: 0.5802251516149254
# Threshold 0.55: 0.533417317495971
# Threshold 0.60: 0.49723917250655536
# Threshold 0.65: 0.477795910308744

# %% [markdown]
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7579 - loss: 0.0516 - precision: 0.8148 - recall: 0.5184
# Test Loss: 0.0516
# Test Accuracy: 0.7579
# Test Recall: 0.5184
# Test Precision: 0.8148
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Confusion Matrix:
# [[4438  699]
#  [1178 2302]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      No_Fire       0.79      0.86      0.83      5137
#         Fire       0.77      0.66      0.71      3480
#
#     accuracy                           0.78      8617
#    macro avg       0.78      0.76      0.77      8617
# weighted avg       0.78      0.78      0.78      8617
