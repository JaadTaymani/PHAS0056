# %%
import numpy as np
import sklearn
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import imageio.v3 as iio
import os
from PIL import Image
import imagehash

# %% [markdown]
# # Data loading and Processing

# %%
Image_size = 96
Batch = 32
Random_seed = 42

train_Bi_raw = tf.keras.utils.image_dataset_from_directory(
    "Training_Bi/",
    validation_split=0.15,
    subset="training",
    seed=Random_seed,
    image_size=(Image_size, Image_size),
    batch_size=None
)

val_Bi_raw = tf.keras.utils.image_dataset_from_directory(
    "Training_Bi/",
    validation_split=0.15,
    subset="validation",
        seed=Random_seed,
        image_size=(Image_size, Image_size),
        batch_size=None
)

test_Bi_raw = tf.keras.utils.image_dataset_from_directory(
    "Test/",
    image_size=(Image_size, Image_size),
    batch_size=None,
    shuffle=False
)
# Out:
# Found 39375 files belonging to 2 classes.
# Using 33469 files for training.
# Found 39375 files belonging to 2 classes.
# Using 5906 files for validation.
# Found 8617 files belonging to 2 classes.

# %%
def focal_loss(gamma, alpha):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        bce = -y_true * tf.math.log(y_pred) - (1 - y_true) * tf.math.log(1 - y_pred)
        p_t = y_true * y_pred + (1 - y_true) * (1 - y_pred)
        focal_weight = alpha * tf.pow(1 - p_t, gamma)
        return tf.reduce_mean(focal_weight * bce)
    return loss


def augment(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.rot90(image, k=tf.random.uniform((), 0, 4, dtype=tf.int32))
    image = tf.image.random_brightness(image, max_delta=0.3)
    image = tf.image.random_contrast(image, lower=0.7, upper=1.4)
    image = tf.image.random_saturation(image, lower=0.6, upper=1.6)
    image = tf.image.random_hue(image, max_delta=0.05)
    
    # Haze - fixed with tf.cond
    haze_intensity = tf.random.uniform((), 0.05, 0.25)
    haze = tf.ones_like(image) * 0.7
    image = tf.cond(
        tf.random.uniform(()) > 0.5,
        lambda: image * (1 - haze_intensity) + haze * haze_intensity,
        lambda: image
    )

    # Blur - fixed with tf.cond
    def apply_blur(img):
        img = tf.expand_dims(img, 0)
        img = tf.nn.avg_pool2d(img, ksize=3, strides=1, padding='SAME')
        return tf.squeeze(img, 0)

    image = tf.cond(
        tf.random.uniform(()) > 0.6,
        lambda: apply_blur(image),
        lambda: image
    )

    image = tf.clip_by_value(image, 0.0, 1.0)
    return image, label

def normalize(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

def compute_class_weights(ds):
    labels = np.array([y.numpy() for _, y in ds])
    counts = np.bincount(labels)
    total = len(labels)
    weights = {i: total / (len(counts) * c) for i, c in enumerate(counts)}
    print(f"Class weights: {weights}")
    return weights

# %%
class_weights = compute_class_weights(train_Bi_raw)

train_ds = (
    train_Bi_raw
    .map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(Batch)
    .prefetch(tf.data.AUTOTUNE)
)
val_ds = (
    val_Bi_raw
    .map(normalize, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(Batch)
    .prefetch(tf.data.AUTOTUNE)
)
test_ds = (
    test_Bi_raw
    .map(normalize, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(Batch)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# Class weights: {0: 0.787542943197327, 1: 1.3694353518821605}

# %%
model = keras.models.Sequential([
    
    keras.layers.Conv2D(8, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(8, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.2),
   
    keras.layers.Conv2D(32, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(32, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(),
    keras.layers.Dropout(0.3),
   
    keras.layers.Conv2D(64, 3, activation='relu', padding='same'),
    keras.layers.GlobalAveragePooling2D(),

    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss=focal_loss(gamma=2.0, alpha=0.25),
    metrics=[
        'accuracy',
        keras.metrics.Recall(name='recall'),
        keras.metrics.Precision(name='precision'),
    ]
)

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=2,
        min_lr=1e-7
    ),
    keras.callbacks.ModelCheckpoint(
        'best_fire_model.keras',
        monitor='val_recall',
        save_best_only=True,
    )
]

history = model.fit(
    train_ds,
    epochs=30,
    validation_data=val_ds,
    class_weight=None,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - accuracy: 0.8397 - loss: 0.0244 - precision: 0.8886 - recall: 0.6415 - val_accuracy: 0.9147 - val_loss: 0.0151 - val_precision: 0.8853 - val_recall: 0.8779 - learning_rate: 1.0000e-04
# Epoch 2/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9284 - loss: 0.0153 - precision: 0.9501 - recall: 0.8484 - val_accuracy: 0.9074 - val_loss: 0.0221 - val_precision: 0.8175 - val_recall: 0.9579 - learning_rate: 1.0000e-04
# Epoch 3/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9321 - loss: 0.0138 - precision: 0.9564 - recall: 0.8528 - val_accuracy: 0.9379 - val_loss: 0.0127 - val_precision: 0.9198 - val_recall: 0.9073 - learning_rate: 1.0000e-04
# Epoch 4/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9336 - loss: 0.0129 - precision: 0.9595 - recall: 0.8543 - val_accuracy: 0.9472 - val_loss: 0.0104 - val_precision: 0.9583 - val_recall: 0.8928 - learning_rate: 1.0000e-04
# Epoch 5/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9392 - loss: 0.0124 - precision: 0.9619 - recall: 0.8678 - val_accuracy: 0.9480 - val_loss: 0.0112 - val_precision: 0.9292 - val_recall: 0.9270 - learning_rate: 1.0000e-04
# Epoch 6/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9423 - loss: 0.0118 - precision: 0.9616 - recall: 0.8771 - val_accuracy: 0.9565 - val_loss: 0.0103 - val_precision: 0.9631 - val_recall: 0.9148 - learning_rate: 1.0000e-04
# Epoch 7/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9431 - loss: 0.0114 - precision: 0.9646 - recall: 0.8762 - val_accuracy: 0.9539 - val_loss: 0.0099 - val_precision: 0.9596 - val_recall: 0.9111 - learning_rate: 5.0000e-05
# Epoch 8/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9443 - loss: 0.0112 - precision: 0.9624 - recall: 0.8818 - val_accuracy: 0.9524 - val_loss: 0.0101 - val_precision: 0.9453 - val_recall: 0.9219 - learning_rate: 5.0000e-05
# Epoch 9/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9457 - loss: 0.0110 - precision: 0.9639 - recall: 0.8843 - val_accuracy: 0.9550 - val_loss: 0.0098 - val_precision: 0.9552 - val_recall: 0.9186 - learning_rate: 5.0000e-05
# Epoch 10/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9453 - loss: 0.0111 - precision: 0.9625 - recall: 0.8846 - val_accuracy: 0.9561 - val_loss: 0.0094 - val_precision: 0.9589 - val_recall: 0.9181 - learning_rate: 5.0000e-05
# Epoch 11/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9477 - loss: 0.0110 - precision: 0.9646 - recall: 0.8894 - val_accuracy: 0.9365 - val_loss: 0.0114 - val_precision: 0.8905 - val_recall: 0.9401 - learning_rate: 5.0000e-05
# Epoch 12/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9474 - loss: 0.0108 - precision: 0.9647 - recall: 0.8883 - val_accuracy: 0.9523 - val_loss: 0.0098 - val_precision: 0.9431 - val_recall: 0.9237 - learning_rate: 5.0000e-05
# Epoch 13/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9491 - loss: 0.0105 - precision: 0.9651 - recall: 0.8928 - val_accuracy: 0.9561 - val_loss: 0.0092 - val_precision: 0.9621 - val_recall: 0.9148 - learning_rate: 2.5000e-05
# Epoch 14/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9480 - loss: 0.0105 - precision: 0.9624 - recall: 0.8924 - val_accuracy: 0.9551 - val_loss: 0.0093 - val_precision: 0.9553 - val_recall: 0.9190 - learning_rate: 2.5000e-05
# Epoch 15/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9493 - loss: 0.0104 - precision: 0.9650 - recall: 0.8935 - val_accuracy: 0.9567 - val_loss: 0.0091 - val_precision: 0.9626 - val_recall: 0.9158 - learning_rate: 2.5000e-05
# Epoch 16/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9499 - loss: 0.0102 - precision: 0.9667 - recall: 0.8935 - val_accuracy: 0.9539 - val_loss: 0.0094 - val_precision: 0.9451 - val_recall: 0.9265 - learning_rate: 1.2500e-05
# Epoch 17/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9494 - loss: 0.0102 - precision: 0.9628 - recall: 0.8961 - val_accuracy: 0.9534 - val_loss: 0.0092 - val_precision: 0.9472 - val_recall: 0.9228 - learning_rate: 1.2500e-05
# Epoch 18/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9499 - loss: 0.0102 - precision: 0.9632 - recall: 0.8971 - val_accuracy: 0.9553 - val_loss: 0.0091 - val_precision: 0.9557 - val_recall: 0.9190 - learning_rate: 6.2500e-06
# Epoch 19/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9502 - loss: 0.0101 - precision: 0.9651 - recall: 0.8960 - val_accuracy: 0.9548 - val_loss: 0.0091 - val_precision: 0.9534 - val_recall: 0.9200 - learning_rate: 6.2500e-06
# Epoch 20/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9510 - loss: 0.0102 - precision: 0.9655 - recall: 0.8979 - val_accuracy: 0.9551 - val_loss: 0.0091 - val_precision: 0.9553 - val_recall: 0.9190 - learning_rate: 6.2500e-06
# Epoch 21/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9496 - loss: 0.0100 - precision: 0.9636 - recall: 0.8958 - val_accuracy: 0.9536 - val_loss: 0.0091 - val_precision: 0.9493 - val_recall: 0.9209 - learning_rate: 3.1250e-06
# Epoch 22/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9510 - loss: 0.0100 - precision: 0.9652 - recall: 0.8981 - val_accuracy: 0.9543 - val_loss: 0.0091 - val_precision: 0.9512 - val_recall: 0.9209 - learning_rate: 3.1250e-06
# Epoch 23/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9511 - loss: 0.0100 - precision: 0.9650 - recall: 0.8987 - val_accuracy: 0.9545 - val_loss: 0.0091 - val_precision: 0.9516 - val_recall: 0.9209 - learning_rate: 1.5625e-06
# Epoch 24/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9511 - loss: 0.0099 - precision: 0.9663 - recall: 0.8975 - val_accuracy: 0.9546 - val_loss: 0.0091 - val_precision: 0.9521 - val_recall: 0.9209 - learning_rate: 1.5625e-06
# Epoch 25/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9502 - loss: 0.0100 - precision: 0.9638 - recall: 0.8972 - val_accuracy: 0.9538 - val_loss: 0.0091 - val_precision: 0.9485 - val_recall: 0.9223 - learning_rate: 7.8125e-07
# Epoch 26/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9517 - loss: 0.0098 - precision: 0.9659 - recall: 0.8994 - val_accuracy: 0.9545 - val_loss: 0.0091 - val_precision: 0.9516 - val_recall: 0.9209 - learning_rate: 7.8125e-07
# Epoch 27/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9502 - loss: 0.0100 - precision: 0.9651 - recall: 0.8961 - val_accuracy: 0.9545 - val_loss: 0.0091 - val_precision: 0.9508 - val_recall: 0.9219 - learning_rate: 3.9062e-07
# Epoch 28/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9511 - loss: 0.0101 - precision: 0.9654 - recall: 0.8984 - val_accuracy: 0.9538 - val_loss: 0.0091 - val_precision: 0.9485 - val_recall: 0.9223 - learning_rate: 3.9062e-07
# Epoch 29/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9510 - loss: 0.0100 - precision: 0.9658 - recall: 0.8975 - val_accuracy: 0.9538 - val_loss: 0.0091 - val_precision: 0.9485 - val_recall: 0.9223 - learning_rate: 1.9531e-07
# Epoch 30/30
# 1046/1046 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.9500 - loss: 0.0100 - precision: 0.9639 - recall: 0.8966 - val_accuracy: 0.9536 - val_loss: 0.0091 - val_precision: 0.9481 - val_recall: 0.9223 - learning_rate: 1.9531e-07

# %%
loss, acc, recall, precision = model.evaluate(test_ds)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {acc:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test Precision: {precision:.4f}")

# Get probabilities
y_pred_prob = model.predict(test_ds)

# 2. Confusion matrix
true_labels = np.concatenate([y.numpy() for _, y in test_ds])

pred_classes = (y_pred_prob > 0.35).astype(int).flatten()
cm = confusion_matrix(true_labels, pred_classes)
print("Confusion Matrix:")
print(cm)

print("\nClassification Report:")
print(classification_report(true_labels, pred_classes, target_names=['No_Fire', 'Fire']))
# Out:
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7579 - loss: 0.0516 - precision: 0.8148 - recall: 0.5184
# Test Loss: 0.0516
# Test Accuracy: 0.7579
# Test Recall: 0.5184
# Test Precision: 0.8148
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Confusion Matrix:
# [[4438  699]
#  [1178 2302]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      No_Fire       0.79      0.86      0.83      5137
#         Fire       0.77      0.66      0.71      3480
#
#     accuracy                           0.78      8617
#    macro avg       0.78      0.76      0.77      8617
# weighted avg       0.78      0.78      0.78      8617

# %%
for t in np.arange(0.25, 0.70, 0.05):
    pred_classes = (y_pred_prob > t).astype(int).flatten()
    print(f"Threshold {t:.2f}:", classification_report(true_labels, pred_classes, target_names=['No_Fire', 'Fire'], output_dict=True)['macro avg']['f1-score'])
# Out:
# Threshold 0.25: 0.6194930089123402
# Threshold 0.30: 0.7366638952987804
# Threshold 0.35: 0.7679141310456695
# Threshold 0.40: 0.7662571221328429
# Threshold 0.45: 0.7551334731433963
# Threshold 0.50: 0.7264434452879647
# Threshold 0.55: 0.696916519173784
# Threshold 0.60: 0.6623694115826979
# Threshold 0.65: 0.6140546932676885

# %% [markdown]
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7579 - loss: 0.0516 - precision: 0.8148 - recall: 0.5184
# Test Loss: 0.0516
# Test Accuracy: 0.7579
# Test Recall: 0.5184
# Test Precision: 0.8148
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Confusion Matrix:
# [[4438  699]
#  [1178 2302]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      No_Fire       0.79      0.86      0.83      5137
#         Fire       0.77      0.66      0.71      3480
#
#     accuracy                           0.78      8617
#    macro avg       0.78      0.76      0.77      8617
# weighted avg       0.78      0.78      0.78      8617
